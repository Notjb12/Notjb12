# %%
from tkinter import *
from tkinter import messagebox
from tkinter.font import Font

window=Tk()
myfont=Font(family="times",size=10, weight="bold")
window.geometry("500x500")

test=Label(text="Calculator", font=myfont)
test.pack()

test1=Label(text="Differentiation and Integeration will be added later",font=myfont)
test1.pack()

def fun():
    data=int(ent.get())
    data1=int(ent1.get())
    dat=data+data1
    messagebox.showinfo("Result!", dat)

def fun1():
    data=int(ent.get())
    data1=int(ent1.get())
    dat=data-data1
    messagebox.showinfo("Result!", dat)

def fun2():
    data=int(ent.get())
    data1=int(ent1.get())
    dat=data*data1
    messagebox.showinfo("Result!", dat)

def fun3():
    data=int(ent.get())
    data1=int(ent1.get())
    dat=data/data1
    messagebox.showinfo("Result!", dat)

def fun4():
    data=int(ent.get())
    data1=int(ent1.get())
    dat=data%data1
    messagebox.showinfo("infobox", dat)


lab=Label(text="Enter your number",font=myfont)
lab.pack()

ent=Entry(font=myfont)
ent.pack(padx=10, pady=10)

lab2=Label(text="Enter your number", font=myfont)
lab2.pack()

ent1=Entry(font=myfont)
ent1.pack(padx=10, pady=10)

leno=Button(

lab23=Label(text="Sum", font=myfont)
lab23.pack()

btn=Button(text="+", command=fun, font=myfont)
btn.pack(padx=10, pady=10)

lab24=Label(text="Sub", font=myfont)
lab24.pack()

btn1=Button(text="-", command=fun1, font=myfont)
btn1.pack(padx=10, pady=10)

lab25=Label(text="Multiply", font=myfont)
lab25.pack()

btn2=Button(text="*", command=fun2, font=myfont)
btn2.pack(padx=10, pady=10)

lab26=Label(text="Div", font=myfont)
lab26.pack()

btn3=Button(text="/", command=fun3, font=myfont)
btn3.pack(padx=10, pady=10)

lab27=Label(text="Modulo", font=myfont)
lab27.pack()

btn4=Button(text="%", command=fun4, font=myfont)
btn4.pack(padx=10, pady=10)


window.mainloop()
