# %%
from pptx import Presentation
from pptx.util import Inches

# Create a PowerPoint presentation object
ppt = Presentation()

# Slide 1: Title Slide
slide_1 = ppt.slides.add_slide(ppt.slide_layouts[0])
title_1 = slide_1.shapes.title
subtitle_1 = slide_1.placeholders[1]
title_1.text = "The Necklace"
subtitle_1.text = "Analysis and Summary\n[Your Name]"

# Slide 2: Introduction to the Author
slide_2 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_2 = slide_2.shapes.title
title_2.text = "Guy de Maupassant"
content_2 = slide_2.placeholders[1]
content_2.text = ("- Brief biography\n"
                  "- Key works\n"
                  "- Literary style")

# Slide 3: Plot Summary
slide_3 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_3 = slide_3.shapes.title
title_3.text = "Plot Summary"
content_3 = slide_3.placeholders[1]
content_3.text = ("- Introduction to Mathilde Loisel and her husband\n"
                  "- The invitation to the ball\n"
                  "- Borrowing the necklace\n"
                  "- The ball night\n"
                  "- Losing the necklace\n"
                  "- Replacing the necklace\n"
                  "- The twist ending")

# Slide 4: Characters
slide_4 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_4 = slide_4.shapes.title
title_4.text = "Main Characters"
content_4 = slide_4.placeholders[1]
content_4.text = ("- Mathilde Loisel: Description and traits\n"
                  "- Monsieur Loisel: Description and traits\n"
                  "- Madame Forestier: Description and traits")

# Slide 5: Themes
slide_5 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_5 = slide_5.shapes.title
title_5.text = "Themes"
content_5 = slide_5.placeholders[1]
content_5.text = ("- The Deceptiveness of Appearances: The fake necklace\n"
                  "- Materialism: Mathilde's obsession with wealth\n"
                  "- Pride and Vanity: How they lead to downfall\n"
                  "- Sacrifice: The Loisels' hard work to repay the debt")

# Slide 6: Literary Devices
slide_6 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_6 = slide_6.shapes.title
title_6.text = "Literary Devices"
content_6 = slide_6.placeholders[1]
content_6.text = ("- Irony: Situational irony in the story's ending\n"
                  "- Symbolism: The necklace as a symbol of wealth and status\n"
                  "- Characterization: How Mathilde and her husband are portrayed\n"
                  "- Setting: Description of the time and place")

# Slide 7: Moral of the Story
slide_7 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_7 = slide_7.shapes.title
title_7.text = "Moral of the Story"
content_7 = slide_7.placeholders[1]
content_7.text = ("- The consequences of vanity and dishonesty\n"
                  "- The importance of honesty and humility")

# Slide 8: Critical Analysis
slide_8 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_8 = slide_8.shapes.title
title_8.text = "Critical Analysis"
content_8 = slide_8.placeholders[1]
content_8.text = ("- Different perspectives on Mathilde's character\n"
                  "- The societal context of the story\n"
                  "- Personal reflections on the story’s message")

# Slide 9: Conclusion
slide_9 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_9 = slide_9.shapes.title
title_9.text = "Conclusion"
content_9 = slide_9.placeholders[1]
content_9.text = ("- Recap of key points\n"
                  "- The enduring relevance of 'The Necklace'")

# Slide 10: Questions & Discussion
slide_10 = ppt.slides.add_slide(ppt.slide_layouts[1])
title_10 = slide_10.shapes.title
title_10.text = "Questions & Discussion"
content_10 = slide_10.placeholders[1]
content_10.text = ("- Invite questions from the audience\n"
                   "- Topics for discussion: What would you do in Mathilde's situation?")

# Save the presentation
ppt_path = "/mnt/data/The_Necklace_Presentation.pptx"
ppt.save(ppt_path)

ppt_path
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from pptx import Presentation
#       2 from pptx.util import Inches
#       4 # Create a PowerPoint presentation object
#
# ModuleNotFoundError: No module named 'pptx'
