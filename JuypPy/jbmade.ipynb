# %%
class main:
    def page(self):
        print("Welcome to JAIBALAJI SYSTEMS")
    def disp(self):
        print("Begin the purchase by seleting the items that u required for..... ")
    def det(self):
        print("For Heading ahed kindly fill your details")

class details(main):
    def namee(self):
        self.namee=str(input("Enter your name"))
    def mob(self):
        self.mob=str(int(input("Enter your mobile number")))
    def go(self):
        print("Your information has been sent to the Head office")

class branch(details):
    def page1(self):
        self.page1=str(input("Enter your required item"))
        print("You selected item is ", self.page1)
        
        if self.page1=="SSD 1TB":
            print("It's price is 1200")
        elif self.page1=="Dell Keyboard":
            print("Its price is 800")
        elif self.page1=="Logitech Keyboard":
            print("Its price is 650")
        elif self.page1=="An Full set of PC with every thing with new version":
            print("Its cost is 100000")
        elif self.page1=="Hp printer M1005":
            print("Its cost is 16000")
        elif self.page1=="Mac Book":
            print("Its cost is 120000")
        else:
            print("Still items is not yet present")
    
    def disp1(self):
        self.disp1=str(int(input("Enter the number of seleccted item required")))
        print("Ok you Count of your required item is", self.disp1)

class another(branch):
    def material(self):
        self.material=str(input("Any other you required to purchase"))
        if self.material=="yes":
            super().page1()
            print("For another Item You should complete this and start from first by entering your details from first..... Later It Will Be updated")
        elif self.material=="no":
            print("Thanks for the choice")
        else:
            print("Print a valid answer")

class store1(another):
    def page2(self):
        self.page2=str(input("Are you confirmed with your purchase"))
        if self.page2=="yes":
            print("Finally YAY Your purchase is confirmed")
        elif self.page2=="no":
            print("Kindly Call to the head office for the further details!")
            break

    

    def selec(self):
        self.sel=str(input("Enter the no of items choosen for the Courier"))
        print(self.sel, "items are chosen for courier")
        print("Packing up the things for you :) !...........")
     
        
    def payment(self):
        self.payment=str(input("Use google pay or paytm to pay the amount"))
        if self.payment=="google pay":
            print("Google pay number is 9865698756")
        elif self.payment=="paytm":
            print("Paytm! You may pay to the number 9842180221")
        else:
            print("the payment method is not present and would be updated later")
            
     
    def code(self):
        self.cde=str(int(input("Enter your gpay code or paytm code for the confirmation of transaction!")))
        print("your code is verified")

     
    def disp2(self):
        print("Your purchased item is Ordered and the price list will be sharedd to your mobile number")
        print("If it not shared yet Kindly call to the number")
        print("Head1-9842180221 Office-9865698756")

       
    def err(self):
        print("Kindly Call to the head office for the further details!")
        print("ENJOY YOUR PURCHASE!!!...............")

     
        
obj=store1()
obj.page()
obj.disp()
obj.det()
obj.namee()
obj.mob()
obj.go()
obj.page1()
obj.disp1()
obj.material()
obj.page2()
obj.selec()
obj.payment()
obj.code()
obj.disp2()
obj.err()
# Out:
#   Cell In[21], line 59
#     break
#     ^
# SyntaxError: 'break' outside loop
