# %%
from abc import ABC,abstractmethod

class Office(ABC):

    @abstractmethod
    def You_Details(self):
        pass

    @abstractmethod
    def About_us(self):
        pass

    @abstractmethod
    def Place_Order(self):
        pass

    @abstractmethod
    def Service_Item(self):
        pass

    @abstractmethod
    def OnSpot_Service(self):
        pass

    @abstractmethod
    def CustomerCare(self):
        pass


class Methods(Office):

    def __init__(self,name):
        self.name=name

    def check(self):
        print("Welcome To JAIBALAJI SYSTEMS")
        print("Place You Order And Have A Wonderfull Purchase Over Here")
        print("\nOffice Owner: - Eswaran 9842180221")
        print("\nOffice Co-Owner: - Sudha 9865698756")


    def You_Details(self):
        self.details=str(input("Enter you name"))
        self.numberrr=str(input("Enter your number"))
        self.loc=str(input("Enter you Adress or location!"))
        print("Please check Your Informationss.....")
        print("\n", self.details)
        print(self.numberrr)
        print(self.loc)


    def About_us(self):
            
            print("You Information had been shared to our Head Quarters")
            print("\nSince It has been a 18 years of sales and service, it is a pleasure to share something about us . We here use to have more orders from the custombers.") 
            print("Service of the systems and anyother thing related to computer, that can be done here. Xerox and Colour printout including binding are also taken in one of our branch")
            print("We have Printer service + Toner Refilling + PC Service, PC Re-format are also be done here.")
            print("With the Pleasure we happy to help you with anything!. For more details you can vist this page fully. Happy to have you hear!")

    def Place_Order(self):
        self.order=str(input("Enter Your Required items required:"))
        print("You Selected Item is", self.order)
        if self.order=="SSD 1TB":
            print("It's price is 1200")
            print("Your Order is placed")
            print("If You want to cancel the Order You may Call to our Head Quarters.......!")
        elif self.order=="Dell Keyboard":
            print("Its price is 800")
        elif self.order=="Logitech Keyboard":
            print("Its price is 650")
        elif self.order=="An Full set of PC with every thing with new version":
            print("Its cost is 100000")
        elif self.order=="Hp printer M1005":
            print("Its cost is 16000")
        elif self.order=="Mac Book":
            print("Its cost is 120000")
        else:
            print("Still items is not yet present")

    def Service_Item(self):
        print("Here you should enter the item that you are needed to service")
        self.ser=str(input("Enter the item:-"))
        if self.ser=="hp printer":
            print("\nTher Reason for the service of", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="lg monitor":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="tonner":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="cpu":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="motherboard":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="SSD drive":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        elif self.ser=="HDD Drive":
            print("\nTher Reason for the service is", self.ser, "Will Be shared")
            print("The Cost will varry according to the problem. The Cost would be maild to you")
            print("If you are ok with the cost you will be done with the problem")
            print("If the cost dosent coorect for you may go with new property or stanby method")
            print("Rest of the things including this will be called to you from our Head Quarters")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")
        else:
            print("\nStil the given item is not been in the list but still it can be taken for the service")
            print("You will recieve a call from the Head Quarter before we recieve the item to us")
            print("Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!")

    def OnSpot_Service(self):
        print("Our Company Will Also On Spot service")
        print("On Spot Service Refers to we will come offline to your location and get done with your problem")
        print("If the problem dosent works we will take to the nearby branch and we wiil get done within the problem in 1hr")


    def CustomerCare(self):
        self.na=str(input("Enter you name"))
        self.nu=str(int(input("Enter you number")))
        self.enq=str(input("Want To Enqiry About us"))
        if self.enq=="yes":
            print("Sure Thing Our Head Quater Will Call to you shortly")
            print("If you didnt recieve a call from us. Please Send a mail to this id")
            print("Mail ID: jaibalajisystems@gmail.com")
        else:
            print("Thanks for the choice")
            print("we are happy to help you with u anytime")
            print("Happy to Help, Seeya LAter :)")


name=[]
obj=Methods(name)
obj.check()

while True:
    print("\n")
    print("1.Enter Your Details")
    print("2.About_us")
    print("3.Place_Order")
    print("4.Service Item")
    print("5.On Spot Service")
    print("6.Customer care")
    print("7.Exit")

    data=int(input("\nPlease Enter Your Opinion"))

    if(data==1):
        obj.You_Details()
    elif(data==2):
        obj.About_us()
    elif(data==3):
        obj.Place_Order()
    elif(data==4):
        obj.Service_Item()
    elif(data==5):
        obj.OnSpot_Service()
    elif(data==6):
        obj.CustomerCare()
    else:
        print("Thank You!!")
        break
# Out:
# Welcome To JAIBALAJI SYSTEMS
# Place You Order And Have A Wonderfull Purchase Over Here
#
# Office Owner: - Eswaran 9842180221
#
# Office Co-Owner: - Sudha 9865698756
#
#
# 1.Enter Your Details
# 2.About_us
# 3.Place_Order
# 4.Service Item
# 5.On Spot Service
# 6.Customer care
# 7.Exit
# Please Enter Your Opinion 4
# Here you should enter the item that you are needed to service
# Enter the item:- tonner
# Ther Reason for the service is tonner Will Be shared
# The Cost will varry according to the problem. The Cost would be maild to you
# If you are ok with the cost you will be done with the problem
# If the cost dosent coorect for you may go with new property or stanby method
# Rest of the things including this will be called to you from our Head Quarters
# Our Pick up van Will Be avaiable in any of you place. We are Happy to Help!!
#
#
# 1.Enter Your Details
# 2.About_us
# 3.Place_Order
# 4.Service Item
# 5.On Spot Service
# 6.Customer care
# 7.Exit
# Please Enter Your Opinion 4
# ...
